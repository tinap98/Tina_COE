# %%
import pandas as pd

# %%
temp=pd.DataFrame(
    {
        'Name':['Tina','grey','blue'],
        'Age':[19,12,20],
        'DOB':['2005-07-11','2009-03-24','2004-06-05']
    })

# %%
temp.dtypes
# Out:
# Name    object
# Age      int64
# DOB     object
# dtype: object

# %%
temp['DOB']=pd.to_datetime(temp['DOB'])

# %%
temp.dtypes
# Out:
# Name            object
# Age              int64
# DOB     datetime64[ns]
# dtype: object

# %%
temp1=pd.DataFrame(
    {
        'Name':['Tina','grey','blue'],
        'Age':[19,12,20],
        'DOB':['11/07/2005','24/03/2009','05/06/2005']
    })

# %%
temp1.dtypes
# Out:
# Name    object
# Age      int64
# DOB     object
# dtype: object

# %%
temp1['DOB']=pd.to_datetime(temp1['DOB'],format='%d/%m/%Y')

# %%
temp1.dtypes
# Out:
# Name            object
# Age              int64
# DOB     datetime64[ns]
# dtype: object

# %%
temp1['Age']=temp1['Age'].astype(float)

# %%
temp1.dtypes
# Out:
# Name            object
# Age            float64
# DOB     datetime64[ns]
# dtype: object

# %%
temp1['Age']=temp1['Age'].astype(str)

# %%
temp1.dtypes
# Out:
# Name            object
# Age             object
# DOB     datetime64[ns]
# dtype: object

# %%
import pandas as pd
uber_data = pd.read_csv("Uber.csv")

# %%
uber_data.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
uber_data['START*'].unique()
# Out:
# array(['Fort Pierce', 'West Palm Beach', 'Cary', 'Jamaica', 'New York',
#        'Elmhurst', 'Midtown', 'East Harlem', 'Flatiron District',
#        'Midtown East', 'Hudson Square', 'Lower Manhattan',
#        "Hell's Kitchen", 'Downtown', 'Gulfton', 'Houston', 'Eagan Park',
#        'Morrisville', 'Durham', 'Farmington Woods', 'Whitebridge',
#        'Lake Wellingborough', 'Fayetteville Street', 'Raleigh',
#        'Hazelwood', 'Fairmont', 'Meredith Townes', 'Apex', 'Chapel Hill',
#        'Northwoods', 'Edgehill Farms', 'Tanglewood', 'Preston',
#        'Eastgate', 'East Elmhurst', 'Jackson Heights', 'Long Island City',
#        'Katunayaka', 'Unknown Location', 'Colombo', 'Nugegoda',
#        'Islamabad', 'R?walpindi', 'Noorpur Shahan', 'Heritage Pines',
#        'Westpark Place', 'Waverly Place', 'Wayne Ridge', 'Weston',
#        'East Austin', 'West University', 'South Congress', 'The Drag',
#        'Congress Ave District', 'Red River District', 'Georgian Acres',
# ...

# %%
uber_data['START*'].value_counts()
# Out:
# START*
# Cary                201
# Unknown Location    148
# Morrisville          85
# Whitebridge          68
# Islamabad            57
#                    ...
# Florence              1
# Ridgeland             1
# Daytona Beach         1
# Sky Lake              1
# Gampaha               1
# Name: count, Length: 177, dtype: int64

# %%
 a=uber_data[uber_data['MILES*']>6]
a
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# 6       1/6/2016 17:30    1/6/2016 17:35  Business   West Palm Beach
# 8       1/10/2016 8:05    1/10/2016 8:25  Business              Cary
# 9      1/10/2016 12:17   1/10/2016 12:44  Business           Jamaica
# 10     1/10/2016 15:08   1/10/2016 15:51  Business          New York
# ...                ...               ...       ...               ...
# 1144  12/29/2016 23:14  12/29/2016 23:47  Business  Unknown Location
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*        PURPOSE*
# 4      West Palm Beach     63.7  Customer Visit
# ...

# %%
 a=uber_data[(uber_data['MILES*']>50) & (uber_data['MILES*']<=100)]
a
# Out:
#           START_DATE*         END_DATE* CATEGORY*            START*  \
# 4      1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# 251   3/19/2016 19:33   3/19/2016 20:39  Business         Galveston
# 295    4/2/2016 12:21    4/2/2016 14:47  Business         Kissimmee
# 296    4/2/2016 16:57    4/2/2016 18:09  Business     Daytona Beach
# 707   8/24/2016 13:01   8/24/2016 15:25  Business  Unknown Location
# 710   8/25/2016 17:19   8/25/2016 19:20  Business  Unknown Location
# 726   8/27/2016 14:01   8/27/2016 15:44  Business            Lahore
# 751    9/6/2016 17:49    9/6/2016 17:49  Business  Unknown Location
# 871  10/28/2016 20:13  10/28/2016 22:00  Business         Asheville
# 873  10/29/2016 17:13  10/29/2016 19:19  Business        Hayesville
# 880  10/30/2016 13:24  10/30/2016 14:37  Business       Bryson City
#
#                 STOP*  MILES*        PURPOSE*
# 4     West Palm Beach    63.7  Customer Visit
# 251           Houston    57.0  Customer Visit
# ...

# %%
b=uber_data.loc[uber_data['START*']=="New York"]
b
# Out:
#          START_DATE*        END_DATE* CATEGORY*    START*             STOP*  \
# 10   1/10/2016 15:08  1/10/2016 15:51  Business  New York            Queens
# 22   1/12/2016 16:02  1/12/2016 17:00  Business  New York     Queens County
# 106  2/14/2016 16:35  2/14/2016 17:02  Business  New York  Long Island City
# 423  6/10/2016 15:19  6/10/2016 16:28  Business  New York           Jamaica
#
#      MILES* PURPOSE*
# 10     10.8  Meeting
# 22     15.1  Meeting
# 106    13.0  Meeting
# 423    16.3  Meeting

# %%
 #miles>15 and only displaying the start,stop and miles columns
a=uber_data[uber_data['MILES*']>15]
a.iloc[:,3:6]
# Out:
#                 START*             STOP*   MILES*
# 4          Fort Pierce   West Palm Beach     63.7
# 9              Jamaica          New York     16.5
# 22            New York     Queens County     15.1
# 25             Houston           Houston     21.9
# 34                Cary           Raleigh     17.1
# ...                ...               ...      ...
# 1089  Unknown Location  Unknown Location     32.3
# 1092  Unknown Location  Unknown Location     23.2
# 1152  Unknown Location  Unknown Location     16.2
# 1154           Gampaha         Ilukwatta     48.2
# 1155               NaN               NaN  12204.7
#
# [155 rows x 3 columns]

# %%
a=uber_data[uber_data['START*'].isin(['New York','Cary','Houston','Jamaica','Lahore']) ]
a
# Out:
#            START_DATE*         END_DATE* CATEGORY*    START*  \
# 7       1/7/2016 13:27    1/7/2016 13:33  Business      Cary
# 8       1/10/2016 8:05    1/10/2016 8:25  Business      Cary
# 9      1/10/2016 12:17   1/10/2016 12:44  Business   Jamaica
# 10     1/10/2016 15:08   1/10/2016 15:51  Business  New York
# 22     1/12/2016 16:02   1/12/2016 17:00  Business  New York
# ...                ...               ...       ...       ...
# 1114   12/26/2016 8:30   12/26/2016 8:41  Business    Lahore
# 1115   12/26/2016 9:05   12/26/2016 9:19  Business    Lahore
# 1116  12/26/2016 10:15  12/26/2016 10:36  Business    Lahore
# 1117  12/26/2016 11:29  12/26/2016 11:42  Business    Lahore
# 1118  12/26/2016 13:09  12/26/2016 13:43  Business    Lahore
#
#                  STOP*  MILES*        PURPOSE*
# 7                 Cary     0.8         Meeting
# 8          Morrisville     8.3         Meeting
# 9             New York    16.5  Customer Visit
# ...

# %%
b=uber_data[(uber_data['START*'].isin(['New York','Cary','Houston', 'North Berkeley Hills', 'San Jose'])) & (uber_data['STOP*'].isin(['Queens','Jamaica','Lahore','Kissimmee', 'Lake Reams', 'Orlando'])) & ((uber_data['MILES*']>10) & (uber_data['MILES*']<=20))]
b
# Out:
#          START_DATE*        END_DATE* CATEGORY*    START*    STOP*  MILES*  \
# 10   1/10/2016 15:08  1/10/2016 15:51  Business  New York   Queens    10.8
# 423  6/10/2016 15:19  6/10/2016 16:28  Business  New York  Jamaica    16.3
#
#     PURPOSE*
# 10   Meeting
# 423  Meeting

# %%
uber_data.dtypes
# Out:
# START_DATE*     object
# END_DATE*       object
# CATEGORY*       object
# START*          object
# STOP*           object
# MILES*         float64
# PURPOSE*        object
# dtype: object

# %%
uber_data['START_DATE*']=pd.to_datetime(uber_data['START_DATE*'],errors='coerce')
uber_data.dtypes
# Out:
# START_DATE*    datetime64[ns]
# END_DATE*              object
# CATEGORY*              object
# START*                 object
# STOP*                  object
# MILES*                float64
# PURPOSE*               object
# dtype: object

# %%
a=uber_data[(uber_data['START_DATE*'].dt.month==1) & (uber_data['START_DATE*'].dt.year==2016)]
a
# Out:
#            START_DATE*        END_DATE* CATEGORY*       START*  \
# 0  2016-01-01 21:11:00   1/1/2016 21:17  Business  Fort Pierce
# 1  2016-01-02 01:25:00    1/2/2016 1:37  Business  Fort Pierce
# 2  2016-01-02 20:25:00   1/2/2016 20:38  Business  Fort Pierce
# 3  2016-01-05 17:31:00   1/5/2016 17:45  Business  Fort Pierce
# 4  2016-01-06 14:42:00   1/6/2016 15:49  Business  Fort Pierce
# ..                 ...              ...       ...          ...
# 56 2016-01-29 13:24:00  1/29/2016 13:47  Business       Durham
# 57 2016-01-29 18:31:00  1/29/2016 18:52  Business         Cary
# 58 2016-01-29 21:21:00  1/29/2016 21:40  Business         Apex
# 59 2016-01-30 16:21:00  1/30/2016 16:33  Business         Cary
# 60 2016-01-30 18:09:00  1/30/2016 18:24  Business         Apex
#
#               STOP*  MILES*         PURPOSE*
# 0       Fort Pierce     5.1   Meal/Entertain
# 1       Fort Pierce     5.0              NaN
# 2       Fort Pierce     4.8  Errand/Supplies
# ...

# %%
a=uber_data[(uber_data['START_DATE*'].dt.month==1) & (uber_data['START_DATE*'].dt.year==2016) & (uber_data['START*']=="Cary")]
a
# Out:
#            START_DATE*        END_DATE* CATEGORY* START*        STOP*  MILES*  \
# 7  2016-01-07 13:27:00   1/7/2016 13:33  Business   Cary         Cary     0.8
# 8  2016-01-10 08:05:00   1/10/2016 8:25  Business   Cary  Morrisville     8.3
# 28 2016-01-15 11:43:00  1/15/2016 12:03  Business   Cary       Durham    10.4
# 30 2016-01-18 14:55:00  1/18/2016 15:06  Business   Cary         Cary     4.8
# 34 2016-01-20 10:36:00  1/20/2016 11:11  Business   Cary      Raleigh    17.1
# 37 2016-01-21 14:25:00  1/21/2016 14:29  Business   Cary         Cary     1.6
# 38 2016-01-21 14:43:00  1/21/2016 14:51  Business   Cary         Cary     2.4
# 39 2016-01-21 16:01:00  1/21/2016 16:06  Business   Cary         Cary     1.0
# 43 2016-01-26 17:17:00  1/26/2016 17:22  Business   Cary         Cary     1.4
# 44 2016-01-26 17:27:00  1/26/2016 17:29  Business   Cary         Cary     0.5
# 45 2016-01-27 09:24:00   1/27/2016 9:31  Business   Cary         Cary     1.8
# ...
