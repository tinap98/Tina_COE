# %%
import pandas as pd
import numpy as np
uber_data = pd.read_csv("Uber.csv")

# %%
a=uber_data.sort_values(by='MILES*')
a.reset_index(inplace=True,drop=True)
a
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       6/8/2016 17:16    6/8/2016 17:18  Business              Soho
# 1      1/26/2016 17:27   1/26/2016 17:29  Business              Cary
# 2      2/17/2016 16:38   2/17/2016 16:43  Business        Katunayaka
# 3      12/25/2016 0:10   12/25/2016 0:14  Business            Lahore
# 4     12/24/2016 22:04  12/24/2016 22:09  Business            Lahore
# ...                ...               ...       ...               ...
# 1151   9/27/2016 21:01    9/28/2016 2:37  Business  Unknown Location
# 1152  10/30/2016 15:22  10/30/2016 18:23  Business         Asheville
# 1153   3/25/2016 22:54    3/26/2016 1:39  Business      Jacksonville
# 1154   3/25/2016 16:52   3/25/2016 22:22  Business             Latta
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 0              Tribeca      0.5  Errand/Supplies
# ...

# %%
uber_data["MILES_CAT"]=np.where(uber_data['MILES*']>100,"Long trip","Short trip")
uber_data
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*   MILES_CAT
# 0          Fort Pierce      5.1   Meal/Entertain  Short trip
# ...

# %%
a=uber_data.sort_values(by=['START*','MILES*'],ascending=[True,False])
a
# Out:
#            START_DATE*         END_DATE* CATEGORY*         START*  \
# 906    11/4/2016 21:04   11/4/2016 21:20  Business          Agnew
# 911    11/6/2016 10:50   11/6/2016 11:04  Business          Agnew
# 908     11/5/2016 8:34    11/5/2016 8:43  Business          Agnew
# 910    11/5/2016 19:20   11/5/2016 19:28  Business          Agnew
# 879   10/30/2016 12:58  10/30/2016 13:18  Business         Almond
# ...                ...               ...       ...            ...
# 889    11/1/2016 17:35   11/1/2016 17:42  Business    Whitebridge
# 890    11/1/2016 19:14   11/1/2016 19:20  Business    Whitebridge
# 516     7/5/2016 16:48    7/5/2016 16:52  Business    Whitebridge
# 870   10/28/2016 18:13  10/28/2016 20:07  Business  Winston Salem
# 1155            Totals               NaN       NaN            NaN
#
#             STOP*   MILES*         PURPOSE*   MILES_CAT
# 906          Cory      4.3              NaN  Short trip
# 911   Renaissance      2.4              NaN  Short trip
# ...

# %%
uber_data["trip_type"] = np.where(uber_data['MILES*'] <= 50, "short trip",  np.where(uber_data['MILES*'] <= 100, "medium trip", "long trip"))
uber_data
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*   MILES_CAT    trip_type
# ...

# %%
uber_data.drop(columns='MILES_CAT')
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*    trip_type
# 0          Fort Pierce      5.1   Meal/Entertain   short trip
# ...

# %%
trip_type_counts = uber_data['trip_type'].value_counts()
print(trip_type_counts)
# Out:
# trip_type
# short trip     1128
# long trip        17
# medium trip      11
# Name: count, dtype: int64

# %%
uber_data.groupby("START*")['MILES*'].agg('mean')
# Out:
# START*
# Agnew                2.775000
# Almond              15.200000
# Apex                 5.341176
# Arabi               17.000000
# Arlington            4.900000
#                       ...
# West University      2.200000
# Weston               4.000000
# Westpark Place       2.182353
# Whitebridge          4.020588
# Winston Salem      133.600000
# Name: MILES*, Length: 177, dtype: float64

# %%
print(uber_data.columns)
# Out:
# Index(['START_DATE*', 'END_DATE*', 'CATEGORY*', 'START*', 'STOP*', 'MILES*',
#        'PURPOSE*', 'MILES_CAT', 'trip_type'],
#       dtype='object')

# %%
grouped = uber_data.groupby('MILES*')['Values'].agg(['sum', 'mean', 'max'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 grouped = uber_data.groupby('MILES*')['Values'].agg(['sum', 'mean', 'max'])
#
# File ~\Anaconda\Lib\site-packages\pandas\core\groupby\generic.py:1951, in DataFrameGroupBy.__getitem__(self, key)
#    1944 if isinstance(key, tuple) and len(key) > 1:
#    1945     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1946     # valid syntax, so don't raise
#    1947     raise ValueError(
#    1948         "Cannot subset columns with a tuple with more than one element. "
#    1949         "Use a list instead."
#    1950     )
# -> 1951 return super().__getitem__(key)
#
# File ~\Anaconda\Lib\site-packages\pandas\core\base.py:244, in SelectionMixin.__getitem__(self, key)
#     242 else:
#     243     if key not in self.obj:
# --> 244         raise KeyError(f"Column not found: {key}")
# ...
