# %%
import pandas as pd

# %%
data=pd.read_csv("online_retail_data.csv")
data
# Out:
#     Product_ID                 Product_Name     Category Sub_Category  Price  \
# 0          101               Wireless Mouse  Electronics  Accessories  25.99
# 1          102                USB-C Charger  Electronics     Chargers  15.99
# 2          103                Running Shoes      Apparel     Footwear  59.99
# 3          104                 Water Bottle       Sports  Accessories  12.49
# 4          105              Gaming Keyboard  Electronics  Accessories  79.99
# 5          106          Notebook Stationery        Books   Stationery   3.99
# 6          107                     Backpack      Apparel         Bags  39.99
# 7          108                     Yoga Mat       Sports    Equipment  24.99
# 8          109  Noise-Cancelling Headphones  Electronics  Accessories  99.99
# 9          110              Fitness Tracker  Electronics      Devices  49.99
# 10         111               Wireless Mouse  Electronics  Accessories  25.99
# 11         112                USB-C Charger  Electronics     Chargers  15.99
# 12         113                Running Shoes      Apparel     Footwear  59.99
# 13         114                 Water Bottle       Sports  Accessories  12.49
# 14         115              Gaming Keyboard  Electronics  Accessories  79.99
# 15         116          Notebook Stationery        Books   Stationery   3.99
# 16         117                     Backpack      Apparel         Bags  39.99
# 17         118                     Yoga Mat       Sports    Equipment  24.99
# 18         119  Noise-Cancelling Headphones  Electronics  Accessories  99.99
# 19         120              Fitness Tracker  Electronics      Devices  49.99
# 20         121               Wireless Mouse  Electronics  Accessories  25.99
# 21         122                USB-C Charger  Electronics     Chargers  15.99
# 22         123                Running Shoes      Apparel     Footwear  59.99
# 23         124                 Water Bottle       Sports  Accessories  12.49
# 24         125              Gaming Keyboard  Electronics  Accessories  79.99
# 25         126          Notebook Stationery        Books   Stationery   3.99
# 26         127                     Backpack      Apparel         Bags  39.99
# 27         128                     Yoga Mat       Sports    Equipment  24.99
# 28         129  Noise-Cancelling Headphones  Electronics  Accessories  99.99
# 29         130              Fitness Tracker  Electronics      Devices  49.99
# 30         131               Wireless Mouse  Electronics  Accessories  25.99
# 31         132                USB-C Charger  Electronics     Chargers  15.99
# 32         133                Running Shoes      Apparel     Footwear  59.99
# 33         134                 Water Bottle       Sports  Accessories  12.49
# 34         135              Gaming Keyboard  Electronics  Accessories  79.99
# 35         136          Notebook Stationery        Books   Stationery   3.99
# 36         137                     Backpack      Apparel         Bags  39.99
# 37         138                     Yoga Mat       Sports    Equipment  24.99
# 38         139  Noise-Cancelling Headphones  Electronics  Accessories  99.99
# 39         140              Fitness Tracker  Electronics      Devices  49.99
# 40         141               Wireless Mouse  Electronics  Accessories  25.99
# 41         142                USB-C Charger  Electronics     Chargers  15.99
# 42         143                Running Shoes      Apparel     Footwear  59.99
# 43         144                 Water Bottle       Sports  Accessories  12.49
# 44         145              Gaming Keyboard  Electronics  Accessories  79.99
# 45         146          Notebook Stationery        Books   Stationery   3.99
# 46         147                     Backpack      Apparel         Bags  39.99
# 47         148                     Yoga Mat       Sports    Equipment  24.99
# 48         149  Noise-Cancelling Headphones  Electronics  Accessories  99.99
# 49         150              Fitness Tracker  Electronics      Devices  49.99
#
#     Discount  Rating  Stock  Sales                       Customer_Reviews
# 0         10     4.5    120     85                   Great quality mouse!
# 1          5     4.2    200    150          Charges quickly and reliably.
# 2         20     4.7     60     45        Very comfortable for long runs.
# 3         15     4.3    500    220                Durable and leak-proof.
# 4         25     4.6     80     30            Good for gaming and typing.
# 5         10     4.0    300    400                 Simple and functional.
# 6         18     4.5    150     95              Spacious and lightweight.
# 7         12     4.8    100     70  Non-slip and great for yoga sessions.
# 8         30     4.4     40     25               Excellent sound quality.
# 9         20     4.5     70     60        Helps track steps and calories.
# 10        10     4.5    120     85                   Great quality mouse!
# 11         5     4.2    200    150          Charges quickly and reliably.
# 12        20     4.7     60     45        Very comfortable for long runs.
# 13        15     4.3    500    220                Durable and leak-proof.
# 14        25     4.6     80     30            Good for gaming and typing.
# 15        10     4.0    300    400                 Simple and functional.
# 16        18     4.5    150     95              Spacious and lightweight.
# 17        12     4.8    100     70  Non-slip and great for yoga sessions.
# 18        30     4.4     40     25               Excellent sound quality.
# 19        20     4.5     70     60        Helps track steps and calories.
# 20        10     4.5    120     85                   Great quality mouse!
# 21         5     4.2    200    150          Charges quickly and reliably.
# 22        20     4.7     60     45        Very comfortable for long runs.
# 23        15     4.3    500    220                Durable and leak-proof.
# 24        25     4.6     80     30            Good for gaming and typing.
# 25        10     4.0    300    400                 Simple and functional.
# 26        18     4.5    150     95              Spacious and lightweight.
# 27        12     4.8    100     70  Non-slip and great for yoga sessions.
# 28        30     4.4     40     25               Excellent sound quality.
# 29        20     4.5     70     60        Helps track steps and calories.
# 30        10     4.5    120     85                   Great quality mouse!
# 31         5     4.2    200    150          Charges quickly and reliably.
# 32        20     4.7     60     45        Very comfortable for long runs.
# 33        15     4.3    500    220                Durable and leak-proof.
# 34        25     4.6     80     30            Good for gaming and typing.
# 35        10     4.0    300    400                 Simple and functional.
# 36        18     4.5    150     95              Spacious and lightweight.
# 37        12     4.8    100     70  Non-slip and great for yoga sessions.
# 38        30     4.4     40     25               Excellent sound quality.
# 39        20     4.5     70     60        Helps track steps and calories.
# 40        10     4.5    120     85                   Great quality mouse!
# 41         5     4.2    200    150          Charges quickly and reliably.
# 42        20     4.7     60     45        Very comfortable for long runs.
# 43        15     4.3    500    220                Durable and leak-proof.
# 44        25     4.6     80     30            Good for gaming and typing.
# 45        10     4.0    300    400                 Simple and functional.
# 46        18     4.5    150     95              Spacious and lightweight.
# 47        12     4.8    100     70  Non-slip and great for yoga sessions.
# 48        30     4.4     40     25               Excellent sound quality.
# 49        20     4.5     70     60        Helps track steps and calories.

# %%
dropC=data.drop(columns=['Stock'])

# %%
import pandas as pd
import seaborn as sns

df=pd.read_csv("train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
num_cols=df.select_dtypes(include=['number'])
y=num_cols['Survived']
x=num_cols.drop(columns='Survived',axis=1)
x.corr()
# Out:
#              PassengerId    Pclass       Age     SibSp     Parch      Fare
# PassengerId     1.000000 -0.035144  0.036847 -0.057527 -0.001652  0.012658
# Pclass         -0.035144  1.000000 -0.369226  0.083081  0.018443 -0.549500
# Age             0.036847 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# SibSp          -0.057527  0.083081 -0.308247  1.000000  0.414838  0.159651
# Parch          -0.001652  0.018443 -0.189119  0.414838  1.000000  0.216225
# Fare            0.012658 -0.549500  0.096067  0.159651  0.216225  1.000000

# %%
sns.heatmap(x.corr(),annot=True,cmap="coolwarm")
# Out:
# <Axes: >

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
data={'Difficulty':['Easy','Medium','Hard','Easy'],'Test Score':[50,60,70,80]}
df=pd.DataFrame(data)
encoder=LabelEncoder()
df['Difficulty_encoded']=encoder.fit_transform(df['Difficulty'])
print(df)
correlation=df['Difficulty_encoded'].corr(df['Test Score'])
print("Correlation:",correlation)
# Out:
#   Difficulty  Test Score  Difficulty_encoded
# 0       Easy          50                   0
# 1     Medium          60                   2
# 2       Hard          70                   1
# 3       Easy          80                   0
# Correlation: -0.1348399724926484

# %%
import pandas as pd
data={'Color':['red','blue','green','blue','red'],
               'Test Score':[50,60,70,80,90]}
df=pd.DataFrame(data)
df_encoded=pd.get_dummies(df,columns=['Color'])
print(df_encoded)
correlation=df_encoded['Color_red'].corr(df_encoded['Test Score'])
print("correlation with red:",correlation)
# Out:
#    Test Score  Color_blue  Color_green  Color_red
# 0          50       False        False       True
# 1          60        True        False      False
# 2          70       False         True      False
# 3          80        True        False      False
# 4          90       False        False       True
# correlation with red: -1.2819751242557094e-17
